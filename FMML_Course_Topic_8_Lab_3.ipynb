# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramesh0325/FMML-LAB-MODLUES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 10:07:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   210MB/s    in 0.3s
#
# 2023-05-03 10:07:37 (210 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26979  1701.06708v1  Quantitative measurement of functional and ana...    cs
# 3941   cs/0504059v1  To learn the multi-class conceptions from the ...    cs
# 35859   1301.6728v1  The need to help people choose among large num...    cs
# 7066   1709.07638v1  We present a scalable and robust Bayesian infe...  stat
# 31154  1802.05591v1  Modern cars are incorporating an increasing nu...    cs
# ...             ...                                                ...   ...
# 25442  1509.01624v1  In 3D image/video acquisition, different views...    cs
# 27742  1704.03915v2  Convolutional neural networks have recently de...    cs
# 11651  1608.07502v1  Anomaly detection plays an important role in m...    cs
# 22165  1506.03850v2  We introduce GAMSEL (Generalized Additive Mode...  stat
# 7840   1803.07658v1  Sparse models for high-dimensional linear regr...  stat
#
#                                                    title  year  \
# 26979  Speech Map: A Statistical Multimodal Atlas of ...  2017
# 3941   A Neural Network Decision Tree for Learning Co...  2005
# 35859   The Decision-Theoretic Interactive Video Advisor  2013
# 7066   Approximate Bayesian Inference in Linear State...  2017
# 31154  Towards End-to-End Lane Detection: an Instance...  2018
# ...                                                  ...   ...
# 25442  Chebyshev and Conjugate Gradient Filters for G...  2015
# 27742  Deep Laplacian Pyramid Networks for Fast and A...  2017
# 11651  Entity Embedding-based Anomaly Detection for H...  2016
# 22165               Generalized Additive Model Selection  2015
# 7840   Graph-based regularization for regression prob...  2018
#
#                                                 keywords
# 26979  [quantitative, measurement, functional, anatom...
# 3941   [conceptions, electroencephalogram, developed,...
# 35859  [information, construction, recommendation, co...
# 7066   [inference, forecasting, attention, intermitte...
# 31154  [incorporating, increasing, automatic, subsequ...
# ...                                                  ...
# 25442  [imagevideo, acquisition, different, enhanceme...
# 27742  [convolutional, demonstrated, reconstruction, ...
# 11651  [detection, important, applications, detecting...
# 22165  [introduce, penalized, likelihood, generalized...
# 7840   [dimensional, regression, substantial, attenti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26979    [quantitative, measurement, functional, anatom...
# 3941     [conceptions, electroencephalogram, developed,...
# 35859    [information, construction, recommendation, co...
# 7066     [inference, forecasting, attention, intermitte...
# 31154    [incorporating, increasing, automatic, subsequ...
#                                ...
# 22946    [factorization, technique, representations, co...
# 29249    [alignment, straightforward, formulation, alig...
# 14349    [scheduling, negotiate, appointments, empirica...
# 7615     [convolutional, generalization, convolutional,...
# 7682     [frequently, interpretability, structure, exte...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8681 words.
# Out of those 4578 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9b82f500-a0e3-44d8-becc-1cb8c782c10e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b82f500-a0e3-44d8-becc-1cb8c782c10e")) {                    Plotly.newPlot(                        "9b82f500-a0e3-44d8-becc-1cb8c782c10e",                        [{"x":["intractable","statistical","associated","estimations","quantitatively","illuminating","understand","principal","applications","dimensional","estimation","construction","functional","reference","measurements","representation","measurement","framework","objectively","quantitative","behaviors","challenge","motionless","characterize","component","transformation","anatomical","scientific","information","correction","characterization","potential","lagrangian","introduce","configuration","variations","variability","differences","quantities","including","computation","multimodal","belonging","developed","irrelevant","presented","consisted","represented","classified","conceptions","recordings","correctly","algorithm","correspondingly","overlapped","calculated","classification","electroencephalogram","represents","preferences","describes","recommender","orderings","recommendation","theoretic","empirically","filtering","distinguishing","constructing","surprisingly","interests","preference","elicitation","probability","incremental","interactive","comparisons","recommending","satisfied","collaborative","performance","eachmovie","immediate","techniques","similarity","intermittent","competing","approximated","approaches","outperforms","approximate","smoothing","inference","magnitude","attention","statistics","forecasting","segmented","automatic","departure","advantages","scalability","receptive","competitive","heuristics","trajectory","computationally","detection","conditioned","autonomous","specialized","increasing","parametrize","detecting","processing","segmentation","subsequent","limitations","aforementioned","incorporating","combination","perspective","expensive","instances","traditional","synthetic","temporally","spatiotemporal","determines","available","appropriate","technique","extensions","correlations","functions","objective","optimization","practical","exploiting","evaluations","currently","connecting","technical","customers","smartphone","indicators","formation","transport","relevance","convolutions","efficient","efficiently","conditions","iterative","initialization","regression","overlapping","convolutional","conditional","following","underlying","additionally","direction","distribution","stochastic","realizable","dominated","experimentally","theoretical","evolutionary","subroutine","important","description","multiobjective","transactions","algorithms","experimental","contribution","submitted","theoretically","determining","hypervolume","significant","calculate","parameters","hierarchies","layerwise","differentiability","structured","necessary","approximation","assumption","retaining","dependencies","hierarchy","variational","rectified","generative","posterior","parameterizes"],"y":[24,169,124,7,25,3,69,24,433,186,205,54,44,53,52,384,42,572,2,70,30,139,2,48,95,59,10,31,681,20,30,160,7,344,24,83,25,69,10,237,161,30,22,180,17,190,2,83,21,2,11,31,790,4,5,28,504,6,36,31,92,19,5,31,42,70,86,12,38,28,16,23,4,159,28,38,32,3,9,34,860,1,10,370,177,0,23,14,438,278,110,16,210,58,162,66,26,34,180,1,74,34,12,104,42,32,91,361,22,53,26,98,3,81,315,207,25,56,7,50,124,57,69,96,202,126,20,17,16,295,74,234,42,25,196,174,327,123,66,49,52,9,33,14,4,11,17,10,32,13,413,160,139,78,30,126,21,408,96,94,125,71,57,199,129,4,12,40,164,64,2,320,71,11,1,578,393,70,16,38,30,3,248,21,229,12,0,1,96,69,101,68,13,51,33,42,9,128,36,0],"type":"bar"},{"x":["intractable","statistical","associated","estimations","quantitativ ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4578,), (4578, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simulator</span> <span style=''>for</span> <span style=''>Hedonic</span> <span style=''>Games</span> <br/><br/><span style=''>Hedonic</span> <span style=''>games</span> <span style=''>are</span> <span style=''>meant</span> <span style=''>to</span> <span style=''>model</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>coalitions</span> <span style=''>of</span> <span style=''>people</span> <span style=''>form</span> <span style=''>and</span> <span style=''>break</span> <span style=''>apart</span> <span style=''>in</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>run</span> <span style='background-color:rgba(255, 0, 0, 0.4068965517241379);'>simulations</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>everything</span> <span style=''>must</span> <span style=''>be</span> <span style=''>done</span> <span style=''>by</span> <span style=''>hand</span> <span style=''>on</span> <span style=''>paper</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>online</span> <span style=''>software</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>visual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simulation</span> <span style=''>of</span> <span style=''>several</span> <span style=''>types</span> <span style=''>of</span> <span style=''>hedonic</span> <span style=''>games</span> <span style=''>httplukemilesorghedonic</span> <span style=''>games</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Monotonic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Laplace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>that</span> <span style=''>creates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>unit</span> <span style=''>from</span> <span style=''>any</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style=''>function</span> <span style=''>using</span> <span style=''>only</span> <span style=''>Gaussian</span> <span style=''>noise</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>in</span> <span style=''>training</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Restricted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>Machines</span> <span style=''>(RBM)</span> <span style=''>that</span> <span style=''>are</span> <span style=''>closely</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>Bregman</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergences</span> <span style=''>This</span> <span style=''>family</span> <span style=''>that</span> <span style=''>we</span> <span style=''>call</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>RBM</span> <span style=''>(Exp</span> <span style=''>RBM)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Harmoniums</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expresses</span> <span style=''>family</span> <span style=''>members</span> <span style=''>through</span> <span style=''>a</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonic</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>linearity</span> <span style=''>for</span> <span style=''>each</span> <span style=''>neuron</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contrastive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>along</span> <span style=''>with</span> <span style=''>our</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Exp</span> <span style=''>RBM</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>useful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>using</span> <span style=''>novel</span> <span style='background-color:rgba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Fixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>an</span> <span style=''>agnostic</span> <span style=''>model</span> <span style=''>where</span> <span style=''>an</span> <span style=''>epsilon</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>samples</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style=''>Our</span> <span style=''>agnostic</span> <span style=''>learning</span> <span style=''>model</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>in</span> <span style=''>fact</span> <span style=''>stronger</span> <span style=''>than</span> <span style=''>Hubers</span> <span style='background-color:rgba(255, 0, 0, 0.8181818181818181);'>contamination</span> <span style=''>model</span> <span style=''>in</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Bernoulli</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style=''>is</span> <span style=''>given</span> <span style=''>Even</span> <span style=''>in</span> <span style=''>this</span> <span style=''>basic</span> <span style=''>setting</span> <span style=''>previous</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>either</span> <span style=''>run</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>time</span> <span style=''>or</span> <span style=''>lose</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>factors</span> <span style=''>in</span> <span style=''>their</span> <span style=''>error</span> <span style='background-color:rgba(255, 0, 0, 0.30386740331491713);'>guarantees</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>agnostic</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>error</span> <span style='background-color:rgba(255, 0, 0, 0.30386740331491713);'>guarantees</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Space</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transferable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Examples</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>examples</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maliciously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbed</span> <span style=''>inputs</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>mislead</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>(ML)</span> <span style=''>models</span> <span style=''>at</span> <span style=''>test</span> <span style=''>time</span> <span style=''>They</span> <span style=''>often</span> <span style=''>transfer</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>example</span> <span style=''>fools</span> <span style=''>more</span> <span style=''>than</span> <span style=''>one</span> <span style=''>model</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>novel</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>inputs</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>span</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contiguous</span> <span style=''>subspace</span> <span style=''>of</span> <span style=''>large</span> <span style=''>(25)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>with</span> <span style=''>higher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>are</span> <span style=''>more</span> <span style=''>likely</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intersect</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>for</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>models</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>is</span> <span style=''>shared</span> <span style=''>thus</span> <span style=''>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transferability</span> <span style=''>In</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitative</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>models</span> <span style=''>decision</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08597122302158273)
# 	experimental (0.14136690647482014)
# 	segmentation (0.07446043165467627)
# 	processing (0.11330935251798561)
# 	representation (0.1381294964028777)
# 	different (0.26151079136690647)
# 	information (0.24496402877697843)
# 	detection (0.12985611510791367)
# 	convolutional (0.14676258992805755)
# 	recognition (0.13920863309352519)
#
# Some Statistics words are:
# 	stochastic (0.1311881188118812)
# 	theoretical (0.14653465346534653)
# 	algorithm (0.3826732673267327)
# 	variables (0.14455445544554454)
# 	statistical (0.1613861386138614)
# 	estimation (0.17722772277227722)
# 	distribution (0.18366336633663366)
# 	dimensional (0.18415841584158416)
# 	inference (0.20495049504950494)
# 	regression (0.18217821782178217)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="06516506-89bc-4961-8da1-4372a10fcce1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06516506-89bc-4961-8da1-4372a10fcce1")) {                    Plotly.newPlot(                        "06516506-89bc-4961-8da1-4372a10fcce1",                        [{"x":["intractable","statistical","associated","estimations","quantitatively","illuminating","understand","principal","applications","dimensional","estimation","construction","functional","reference","measurements","representation","measurement","framework","objectively","quantitative","behaviors","challenge","motionless","characterize","component","transformation","anatomical","scientific","information","correction","characterization","potential","lagrangian","introduce","configuration","variations","variability","differences","quantities","including","computation","multimodal","belonging","developed","irrelevant","presented","consisted","represented","classified","conceptions","recordings","correctly","algorithm","correspondingly","overlapped","calculated","classification","electroencephalogram","represents","preferences","describes","recommender","orderings","recommendation","theoretic","empirically","filtering","distinguishing","constructing","surprisingly","interests","preference","elicitation","probability","incremental","interactive","comparisons","recommending","satisfied","collaborative","performance","eachmovie","immediate","techniques","similarity","intermittent","competing","approximated","approaches","outperforms","approximate","smoothing","inference","magnitude","attention","statistics","forecasting","segmented","automatic","departure","advantages","scalability","receptive","competitive","heuristics","trajectory","computationally","detection","conditioned","autonomous","specialized","increasing","parametrize","detecting","processing","segmentation","subsequent","limitations","aforementioned","incorporating","combination","perspective","expensive","instances","traditional","synthetic","temporally","spatiotemporal","determines","available","appropriate","technique","extensions","correlations","functions","objective","optimization","practical","exploiting","evaluations","currently","connecting","technical","customers","smartphone","indicators","formation","transport","relevance","convolutions","efficient","efficiently","conditions","iterative","initialization","regression","overlapping","convolutional","conditional","following","underlying","additionally","direction","distribution","stochastic","realizable","dominated","experimentally","theoretical","evolutionary","subroutine","important","description","multiobjective","transactions","algorithms","experimental","contribution","submitted","theoretically","determining","hypervolume","significant","calculate","parameters","hierarchies","layerwise","differentiability","structured","necessary","approximation","assumption","retaining","dependencies","hierarchy","variational","rectified","generative","posterior","parameterizes","procedures","consisting","variables","investigate","comparable","generalisation","selection","demonstrate","validation","guarantees","convergence","strategies","estimator","partially","accelerate","treatment","desirable","estimating","treatments","properties","alternative","asymptotic","practitioners","prediction","orthogonal","exogenous","estimators","sequentially","dimensionality","equivalent","coefficients","attrition","initiatives","incomplete","robustness","anticipate","assessment","decreasing","predicted","predicting","predictions","comprehensive","classical","industries","ensembles","retention","occurrence","regressions","distinguish","increasingly","significantly","censoring","identification","determine ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	intermittent
# 	layerwise
# 	parameterizes
# 	attrition
# 	retention
# 	censoring
# 	penalization
# 	cumulants
# 	invariably
# 	preferably
# 	econometrics
# 	sinusoidal
# 	astronomy
# 	disentanglement
# 	fluctuate
# 	deconvnet
# 	overtraining
# 	exemplifies
# 	decontamination
# 	lengthscale
# Some words which never appear in Statistics papers:
# 	illuminating
# 	motionless
# 	consisted
# 	conceptions
# 	orderings
# 	smartphone
# 	realizable
# 	multiobjective
# 	hypervolume
# 	programmers
# 	prefrontal
# 	osteoporosis
# 	institutional
# 	examinations
# 	impairment
# 	constrain
# 	psycholinguistic
# 	conversational
# 	neurologists
# 	neurological

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0885168941874115e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667
